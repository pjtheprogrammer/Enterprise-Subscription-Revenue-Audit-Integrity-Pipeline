# %%
import pandas as pd
import datetime as dt
import sqlalchemy as sqa

df = pd.read_csv("C:\\Users\\SURF\\ravenstack_subscriptions.csv")
df.start_date = df.start_date.apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').date())
df.end_date = df.end_date.fillna('null')
df.end_date = df.end_date.apply(lambda x: dt.datetime.strptime(x, '%Y-%m-%d').date() if x != 'null' else 'null')

engine = sqa.create_engine('postgresql+psycopg2://postgres:vincent23@localhost:5432/full_stack_saas_project')

with engine.connect() as connection:
    df.to_sql('integrity_check', con = connection, index = False)
